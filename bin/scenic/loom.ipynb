# %%
import loompy as lp
import scanpy as sc

# %%
path_loom = "/cellar/users/aklie/SCENIC+_gene_based-1.loom"

# %%
# Load the loom file
ds = lp.connect(path_loom, spec_version="2.0.0")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Load the loom file
# ----> 2 ds = lp.connect(path_loom, spec_version="2.0.0")
#
# File ~/opt/miniconda3/envs/test_scenicplus_dev/lib/python3.11/site-packages/loompy/loompy.py:1515, in connect(filename, mode, validate, spec_version)
#    1489 def connect(filename: str, mode: str = 'r+', *, validate: bool = True, spec_version: str = "3.0.0") -> LoomConnection:
#    1490 	"""
#    1491 	Establish a connection to a .loom file.
#    1492
#    (...)
#    1513 		Note: if validation is requested, an exception is raised if validation fails.
#    1514 	"""
# -> 1515 	return LoomConnection(filename, mode, validate=validate)
#
# File ~/opt/miniconda3/envs/test_scenicplus_dev/lib/python3.11/site-packages/loompy/loompy.py:86, in LoomConnection.__init__(self, filename, mode, validate)
# ...
